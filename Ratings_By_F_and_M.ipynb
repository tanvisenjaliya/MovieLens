# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
rate = pd.read_csv(r"C:\Users\ta20111785\Extras\projects\MovieLens\movies_integrated.csv")

# %%
#sns.catplot(x="Gender", y="rating", data=rate)

# %%
#sns.catplot(x="Gender", y="rating", kind="box",data=rate)
#sns.catplot(x="movie_id", y="rating", hue="Gender",kind="swarm", data=rate)

# %%
row1
# Out:
#         Unnamed: 0  user_id Gender  Age  preference   5col  movie_id  \
# 381087      381087     2227      M   50          14  60016      1625
# 369141      369141     2158      M   25          12  60618        69
# 415409      415409     2502      M   56          13  49423       150
# 718537      718537     4305      F   45          17  27616      1124
# 446814      446814     2753      F   50          20  27516      1260
# 343323      343323     2017      M   25          17  35808       480
# 588802      588802     3591      M   35           6  96158      1090
# 180449      180449     1128      M   25           1  72701      3042
# 198869      198869     1221      M   18           0  19134      2450
# 951696      951696     5749      M   25           2  94117      1218
# 710169      710169     4260      M   25          16  59079      1348
# 243897      243897     1470      M   18           4  94118      1855
# 946290      946290     5716      M    1          10  03756      1073
# ...

# %%
sns.catplot(x="movie_id", y="rating",hue="Gender", kind="swarm",data=row1)
